# %%
# Replace with your actual GitHub username/repo
# !git clone https://github.com/salaheddinegv-phar/tensorflow-food-vision.git
# %cd tensorflow-food-vision/
# !pip install -q -r requirements.txt

# %%
import tensorflow as tf
print("GPU available:", tf.config.list_physical_devices('GPU'))

# %%
# !python src/train.py \
  --train_dir "/content/tensorflow-food-vision/Food-Vision-project/data/101_food_classes_10_percent/train" \
  --test_dir "/content/tensorflow-food-vision/Food-Vision-project/data/101_food_classes_10_percent/test" \
  --initial_epochs 15 \
  --fine_tune_epochs 5 \
  --experiment_name "EfficientnetV2B0_10pct" \
  --checkpoint_dir "models/checkpoints" \
  --model_save_path "models/food_classifier.keras"
